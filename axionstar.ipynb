# %%
import numpy as np
import matplotlib.pyplot as plt
from classes.particles import Particles
from classes.axionstar import AxionStar

# %%
M_AS = 1
AS = AxionStar(M_AS, Particles.axionmass, vdisp_type='Flat')

# %%
AS.center = [0,0,0]
AS.encl_mass(np.array([np.array([AS.radius99(), 0, 0]) + AS.center]))[0]
# Out:
# 0.9901949533280651

# %%
plt.plot(AS.density_profile()[0], AS.density_profile()[1]);

# %%
AS.center, AS.vcenter = [1e14, 6e3, 0.], [-300., 0, 0]
nparticles = 10000
positions, velocities = AS.draw_particles(nparticles)

# %%
plt.scatter(positions.T[0], positions.T[1], s = 1)
ax = plt.gca()
ax.set_aspect('equal')

# %%
velocities
# Out:
# array([[-2.99999285e+02,  1.55416991e-03,  5.58935588e-03],
#        [-2.99999745e+02, -2.00659203e-03, -5.61576854e-04],
#        [-3.00003354e+02, -1.66827022e-03, -4.35285721e-03],
#        ...,
#        [-2.99998868e+02,  4.64876177e-03,  1.45591071e-03],
#        [-2.99998904e+02,  3.18731289e-03, -6.71837668e-03],
#        [-3.00009491e+02, -1.84143713e-03,  9.23119138e-03]])
